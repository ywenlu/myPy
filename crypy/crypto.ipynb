# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.plotly as py
import plotly.graph_objs as go
import datetime
import itertools
# %matplotlib inline

# %%
nms = ['BCH', 'BTC', 'ETC', 'ETH', 'LTC', 'XRP']

# %%
nm = 'BTC'
df = pd.read_csv('C:/Users/Wenlu/Documents/DataScience/Data/{}.csv'.format(nm),parse_dates =['time'],infer_datetime_format=True)
#df=df.set_index('time')
df['delta']=df['close']-df['open']
df['incre']=(df['close']-df['open'])/df['open']
df['weekday']=df['time'].apply(lambda x: x.weekday())
df.head()
# Out:
#         time  close  high   low  open  volumefrom  volumeto  delta     incre  \
# 0 2011-08-27   6.14  6.14  6.01  6.01      1.6400      9.87   0.13  0.021631
# 1 2011-08-28   6.40  6.40  6.20  6.14      0.4928      3.10   0.26  0.042345
# 2 2011-08-29   6.40  6.40  6.40  6.40      0.0000      0.00   0.00  0.000000
# 3 2011-08-30   6.40  6.40  6.40  6.40      0.0000      0.00   0.00  0.000000
# 4 2011-08-31   6.40  6.40  6.40  6.40      0.0000      0.00   0.00  0.000000
#
#    weekday
# 0        5
# 1        6
# 2        0
# 3        1
# 4        2

# %%
df['y']=df.loc[1:,'close'].reset_index(drop=True)

# %%
df.head()
# Out:
#         time  close  high   low  open  volumefrom  volumeto  delta     incre  \
# 0 2011-08-27   6.14  6.14  6.01  6.01      1.6400      9.87   0.13  0.021631
# 1 2011-08-28   6.40  6.40  6.20  6.14      0.4928      3.10   0.26  0.042345
# 2 2011-08-29   6.40  6.40  6.40  6.40      0.0000      0.00   0.00  0.000000
# 3 2011-08-30   6.40  6.40  6.40  6.40      0.0000      0.00   0.00  0.000000
# 4 2011-08-31   6.40  6.40  6.40  6.40      0.0000      0.00   0.00  0.000000
#
#    weekday    y
# 0        5  6.4
# 1        6  6.4
# 2        0  6.4
# 3        1  6.4
# 4        2  6.4

# %%
fig, ax = plt.subplots(2,3,figsize=(12,6))
for k,nm in enumerate(nms):
    df = pd.read_csv('C:/Users/Wenlu/Documents/DataScience/Data/{}.csv'.format(nm),parse_dates =['time'],infer_datetime_format=True)
    df=df[df['time']>datetime.date(2017,5,1)]
    #df=df.set_index('time')
    df['delta']=df['close']-df['open']
    df['weekday']=df['time'].apply(lambda x: x.weekday())
    res= list(df.groupby('weekday')['close'].mean())
    diffmat=np.zeros((7,7))
    for i,j in list(itertools.combinations(range(7), 2)):
        diffmat[i,j]=res[i]- res[j] 
    sns.heatmap(diffmat,ax=ax[k/3,k%3])
    ax[k/3,k%3].set_title(nm)

# %%
fig, ax = plt.subplots(2,3,figsize=(12,12))
for i,nm in enumerate(nms):
    df = pd.read_csv('C:/Users/Wenlu/Documents/DataScience/Data/{}.csv'.format(nm),parse_dates =['time'],infer_datetime_format=True)
    #df=df.set_index('time')
    df['delta']=df['close']-df['open']
    df['weekday']=df['time'].apply(lambda x: x.weekday())
    df.groupby('weekday')['delta'].mean().plot(ax=ax[i/3,i%3])
    ax[i/3,i%3].set_title(nm)

# %%
dfs=[]
for nm in nms:
    df = pd.read_csv('C:/Users/Wenlu/Documents/DataScience/Data/{}.csv'.format(nm),parse_dates =['time'],infer_datetime_format=True)
    df=df.set_index('time')
    df = (df['close']-df['open'])/df['open']
    df=df.rename(nm)
    dfs.append(df)
dfall=pd.concat(dfs,axis=1)

# %%
dfs=[]
for nm in nms:
    df = pd.read_csv('C:/Users/Wenlu/Documents/DataScience/Data/{}.csv'.format(nm),parse_dates =['time'],infer_datetime_format=True)
    df=df.set_index('time')
    df = df['open']
    df=df.rename(nm)
    dfs.append(df)

# %%
dfa=dfall[datetime.date(2017,5,1):]

# %%
fig, ax = plt.subplots(2,3,figsize=(12,12))
for i,col in enumerate(dfa.columns.values):
    s=dfa[col]
    s=s[~s.isnull()]
    sns.distplot(s,ax=ax[i/3,i%3])
    ax[i/3,i%3].set_title(col)

# %%
dfa.plot(figsize=(12,12))

# %%
sns.heatmap(dfa.corr())

# %%
plotly.offline.init_notebook_mode(connected=True)
trace = go.Candlestick(x=df.time,
                       open=df.open,
                       high=df.high,
                       low=df.low,
                       close=df.close)
data = [trace]
plotly.offline.iplot(data, filename='candlestick_datetime')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="6c76af73-e05c-44a7-9cb6-8f7abc8c65c1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6c76af73-e05c-44a7-9cb6-8f7abc8c65c1", [{"open": [6.01, 6.14, 6.4, 6.4, 6.4, 6.4, 6.4, 5.78, 5.83, 5.83, 5.03, 4.54, 4.95, 4.77, 3.5, 3.49, 3.66, 4.38, 4.34, 4.1, 3.5, 3.5, 3.57, 3.75, 4.0, 4.47, 4.07, 4.08, 4.23, 4.1, 4.0, 3.7, 3.68, 3.59, 3.55, 3.85, 3.81, 3.78, 3.7, 3.75, 3.68, 3.55, 3.29, 2.89, 2.98, 3.09, 2.93, 3.06, 2.96, 2.97, 2.76, 2.59, 1.92, 1.75, 1.62, 1.74, 1.81, 2.26, 2.27, 1.87, 2.0, 1.98, 2.16, 2.33, 2.57, 2.3, 2.3, 2.32, 2.42, 2.31, 2.27, 2.18, 2.17, 2.21, 2.23, 2.15, 2.12, 2.22, 2.17, 2.17, 1.58, 1.72, 1.92, 1.69, 1.52, 1.62, 1.64, 1.73, 1.75, 1.7, 1.85, 1.83, 1.85, 1.85, 1.92, 2.13, 2.21, 2.28, 2.3, 2.06, 2.12, 2.14, 2.23, 2.19, 2.26, 2.23, 2.34, 2.48, 2.34, 2.42, 2.41, 2.46, 2.45, 2.43, 2.46, 2.7, 3.12, 3.02, 3.0, 3.07, 3.02, 3.28, 3.12, 3.11, 3.28, 3.21, 3.38, 3.55, 4.11, 4.02, 3.7, 4.23, 5.47, 5.2, 5.25, 5.43, 4.9, 5.2, 5.5, 5.28, 5.15, 5.31, 5.43, 5.16, 4.45, 4.51, 4.95, 5.05, 4.8, 5.0, 4.93, 4.95, 4.
, 8.49, 8.7, 8.74, 8.74, 8.66, 9.1, 9.21, 9.09, 9.08, 9.1, 9.1, 9.4, 9.49, 9.5, 9.5, 9.45, 9.33, 9.5, 9.73, 9.66, 9.69, 9.53, 9.62, 10.03, 10.21, 10.32, 10.4, 10.29, 10.32, 10.38, 10.56, 10.53, 10.54, 10.54, 10.4, 10.23, 10.3, 10.27, 10.32, 10.4, 10.25, 10.29, 10.15, 10.2, 10.3, 10.29, 10.28, 10.15, 10.1, 10.14, 10.23, 10.17, 10.23, 10.2, 10.2, 10.2, 10.21, 10.34, 10.71, 10.74, 10.8, 11.0, 10.79, 10.75, 10.8, 10.82, 11.17, 11.7, 11.73, 11.71, 11.83, 12.71, 13.12, 13.32, 12.75, 12.99, 13.05, 13.2, 13.79, 14.56, 14.75, 15.35, 15.1, 14.37, 14.76, 15.02, 15.2, 15.84, 16.26, 16.85, 17.44, 17.47, 18.0, 18.71, 18.43, 20.12, 20.2, 20.44, 20.18, 20.34, 22.26, 22.5, 22.51, 23.0, 22.68, 22.66, 23.21, 24.0, 23.5, 25.64, 26.7, 26.97, 26.9, 28.23, 31.47, 32.31, 31.57, 33.59, 35.8, 35.7, 37.15, 33.18, 36.42, 36.52, 36.4, 36.5, 36.65, 39.5, 46.0, 49.82, 56.0, 53.97, 49.65, 55.15, 56.75, 60.93, 69.25, 70.63, 70.86, 72.27, 73.74, 80.77, 92.19, 102.99, 104.0, 108.5, 111.97, 127.16, 143.63, 180.1, 127.01, 92.0, 88.0, 71.0, 67.4, 63.0, 51.1, 71.5, 82.5, 91.51, 98.15, 92.0, 95.0, 109.68, 119.0, 1 ...

# %%
type(df.iloc[0,0])
# Out:
# pandas.tslib.Timestamp

# %%
plt.plot(df['time'],df['close'])

# %%
from matplotlib.finance import candlestick_ohlc
import matplotlib.dates as mdates
#df["time"] = df["time"].apply(lambda d: mdates.date2num(d.to_pydatetime()))
fig, ax = plt.subplots(1,1)
candlestick_ohlc(ax,df['open'],df['high'],df['low'],df['close'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-3fad16107a3a> in <module>()
#       3 #df["time"] = df["time"].apply(lambda d: mdates.date2num(d.to_pydatetime()))
#       4 fig, ax = plt.subplots(1,1)
# ----> 5 candlestick_ohlc(ax,df['open'],df['high'],df['low'],df['close'])
#
# C:\Users\Wenlu\Anaconda2\lib\site-packages\matplotlib\finance.pyc in candlestick_ohlc(ax, quotes, width, colorup, colordown, alpha)
#     737     return _candlestick(ax, quotes, width=width, colorup=colorup,
#     738                         colordown=colordown,
# --> 739                         alpha=alpha, ochl=False)
#     740
#     741
#
# C:\Users\Wenlu\Anaconda2\lib\site-packages\matplotlib\finance.pyc in _candlestick(ax, quotes, width, colorup, colordown, alpha, ochl)
#     785             t, open, close, high, low = q[:5]
#     786         else:
# --> 787             t, open, high, low, close = q[:5]
#     788
#     789         if close >= open:
#
# IndexError: invalid index to scalar variable.
